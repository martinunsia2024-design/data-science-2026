# %% [markdown]
# # UTS Data Science - Dokumentasi Praktikum
# ## Pertemuan 1: Pengenalan Data Science
#
# * **Nama Lengkap:** Martin Hotmatua Siregar
# * **NIM:** 240401020111
# * **Kelas:** IF403
# * **Program Studi:** PJJ Informatika
# * **Instansi:** Universitas Siber Asia

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Mahasiswa Informatika"
angkatan = 2024              # Integer
ipk = 3.75                   # Float
aktif = True                 # Boolean

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Mahasiswa Informatika
# Angkatan : 2024
# IPK      : 3.75
# Aktif    : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("Tools Data Science yang akan kita pelajari:")

for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Martin Hotmatua Siregar", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Martin Hotmatua Siregar dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan & Refleksi Pembelajaran (Sesi 1)
#
# ### 1. Apa yang Dipelajari?
# Di pertemuan pertama ini, saya belajar tentang dasar-dasar Data Science. Ternyata bidang ini merupakan gabungan dari tiga ilmu utama, yaitu Matematika/Statistika, Pemrograman (Ilmu Komputer), dan pemahaman bisnis atau domain ilmu tertentu. Selain itu, saya juga mempelajari siklus pengerjaan proyek data lewat metode CRISP-DM. Di bagian praktikum, saya berhasil mencoba beberapa sintaks dasar Python di Google Colab, mulai dari pembuatan variabel, perintah looping, hingga membuat fungsi (function) sederhana.
#
# ### 2. Temuan Utama
# * Data Science itu bukan cuma soal mengetik kode atau memakai tools, tapi bagaimana kita berpikir logis untuk menyelesaikan masalah nyata menggunakan data.
# * Dalam metode CRISP-DM, tahap persiapan data (Data Preparation) ternyata adalah bagian yang paling menyita waktu, bisa mengambil porsi sekitar 60% sampai 80% dari total pengerjaan proyek.
# * Tahap awal atau Business Understanding sangat krusial. Jika kita salah mengartikan kebutuhan bisnis atau masalah di awal, kemungkinan besar proyek data science tersebut akan gagal.
#
# ### 3. Keterbatasan & Pertanyaan yang Muncul
# * **Keterbatasan:** Praktikum kali ini masih sangat dasar karena datanya dibuat manual langsung di dalam kode program, belum mencoba mengimpor dataset eksternal (seperti file CSV atau Excel).
# * **Pertanyaan:** Bagaimana cara mendeteksi data yang rusak atau kosong jika kita nanti mengolah dataset riil yang ukurannya sangat besar? Serta seperti apa contoh nyata penerapan metode CRISP-DM ini pada industri di Indonesia?
